# %%
import numpy as np #is use for numerical computing
import pandas as pd #is use for data manipulation and analysis
from sklearn.model_selection import train_test_split #use to split data into 2 part so that we can train and test the model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer #use  module is designed to convert text data into numerical features.

# %%
from sklearn.linear_model import LogisticRegression#used for implementing linear regression models, which analyze the relationship between two or more variables
from sklearn.metrics import accuracy_score#provides a wide range of functions to evaluate the performance of machine learning models

# %%
df = pd.read_csv('mail_data.csv')# store the data

# %%
print(df)#it will print the first and last 5 row
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
data = df.where((pd.notnull(df)),'')

# %%
data.head(10)
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# 5     spam  FreeMsg Hey there darling it's been 3 week's n...
# 6      ham  Even my brother is not like to speak with me. ...
# 7      ham  As per your request 'Melle Melle (Oru Minnamin...
# 8     spam  WINNER!! As a valued network customer you have...
# 9     spam  Had your mobile 11 months or more? U R entitle...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
data.shape
# Out:
# (5572, 2)

# %%
data.loc[data['Category']=='spam','Category',]=0

# %%
data.loc[data['Category']=='ham','Category',]=1

# %%
x= data['Message']
print(x)
y = data['Category']
print(y)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: Message, Length: 5572, dtype: object
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: Category, Length: 5572, dtype: object

# %%
x_train, x_test, y_train, y_test, = train_test_split(x,y,test_size=0.2,random_state =3)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)

# %%
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TfidfVectorizer
feature_extraction = TfidfVectorizer(min_df=1, stop_words='english', lowercase=True)

# Fit on training data and transform both training and test data
x_train_features = feature_extraction.fit_transform(x_train)
x_test_features = feature_extraction.transform(x_test)  # Use transform here


# Ensure the labels are integers
y_train = y_train.astype('int')
y_test = y_test.astype('int')

# %%
print(x_train)
# Out:
# 3075                  Don know. I did't msg him recently.
# 1787    Do you know why god created gap between your f...
# 1614                         Thnx dude. u guys out 2nite?
# 4304                                      Yup i'm free...
# 3266    44 7732584351, Do you want a New Nokia 3510i c...
#                               ...
# 789     5 Free Top Polyphonic Tones call 087018728737,...
# 968     What do u want when i come back?.a beautiful n...
# 1667    Guess who spent all last night phasing in and ...
# 3321    Eh sorry leh... I din c ur msg. Not sad alread...
# 1688    Free Top ringtone -sub to weekly ringtone-get ...
# Name: Message, Length: 4457, dtype: object

# %%
print(x_train_features)
# Out:
#   (0, 2329)	0.38783870336935383
#   (0, 3811)	0.34780165336891333
#   (0, 2224)	0.413103377943378
#   (0, 4456)	0.4168658090846482
#   (0, 5413)	0.6198254967574347
#   (1, 3811)	0.17419952275504033
#   (1, 3046)	0.2503712792613518
#   (1, 1991)	0.33036995955537024
#   (1, 2956)	0.33036995955537024
#   (1, 2758)	0.3226407885943799
#   (1, 1839)	0.2784903590561455
#   (1, 918)	0.22871581159877646
#   (1, 2746)	0.3398297002864083
#   (1, 2957)	0.3398297002864083
#   (1, 3325)	0.31610586766078863
#   (1, 3185)	0.29694482957694585
#   (1, 4080)	0.18880584110891163
#   (2, 6601)	0.6056811524587518
#   (2, 2404)	0.45287711070606745
#   (2, 3156)	0.4107239318312698
#   (2, 407)	0.509272536051008
#   (3, 7414)	0.8100020912469564
#   (3, 2870)	0.5864269879324768
#   (4, 2870)	0.41872147309323743
#   (4, 487)	0.2899118421746198
#   :	:
#   (4454, 2855)	0.47210665083641806
#   (4454, 2246)	0.47210665083641806
#   (4455, 4456)	0.24920025316220423
#   (4455, 3922)	0.31287563163368587
# ...

# %%
model= LogisticRegression()

# %%
model.fit(x_train_features,y_train)
# Out:
# LogisticRegression()

# %%
prediction_on_training_data = model.predict(x_train_features)
accuracy_on_training_data = accuracy_score(y_train, prediction_on_training_data)

# %%
print('Accuracy on train data:- ',accuracy_on_training_data)
# Out:
# Accuracy on train data:-  0.9676912721561588

# %%
# Make predictions on the test data
prediction_on_test_data = model.predict(x_test_features)

# Calculate accuracy
accuracy_on_test_data = accuracy_score(y_test, prediction_on_test_data)

print("Accuracy on test data:", accuracy_on_test_data)
# Out:
# Accuracy on test data: 0.9668161434977578

# %%
in_data = ["Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat..."]
in_data_feature = feature_extraction.transform(in_data)
prediction = model.predict(in_data_feature)
print(prediction)
if prediction[0] == 1:
    print('ham mail')
else:
    print('spam mail')
# Out:
# [1]
# ham mail

# %% [markdown]
# to check spam use thias data
#
#
# Prize Scam:
#
# "Congratulations! You've won a $1,000 gift card. Click here to claim your prize."
#
# Lottery Scam:
#
# "You've been selected as the winner of the international lottery! Please provide your personal details to receive your winnings."
#
# Phishing Scam:
#
# "Your account has been compromised. Click this link to reset your password immediately."
#
# Investment Scam:
#
# "Get rich quick! Invest $100 and earn $10,000 in a week. Limited time offer!"
#
# Job Offer Scam:
#
# "We have an exciting job offer for you! Earn thousands working from home. No experience necessary. Click here to apply."
#
# Free Trial Scam:
#
# "Try our product for free! Just pay a small shipping fee. Click here to get started."

# %%
in_data = ["Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"]
in_data_feature = feature_extraction.transform(in_data)  # corrected typo
prediction = model.predict(in_data_feature)  # corrected typo
print(prediction)
if prediction[0] == 1:
    print('ham mail')
else:
    print('spam mail')
# Out:
# [0]
# spam mail

# %%
in_data = ["Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...."]
in_data_feature = feature_extraction.transform(in_data)  # corrected typo
prediction = model.predict(in_data_feature)  # corrected typo
print(prediction)
if prediction[0] == 1:
    print('ham mail')
else:
    print('spam mail')
# Out:
# [1]
# ham mail

# %% [markdown]
# for ham mail use one of this
#
# Work Communication:
#
# "Hi Team, I hope this email finds you well. I wanted to remind everyone about the upcoming project meeting on Friday at 10:00 AM. Please ensure that you have completed your assigned tasks and be prepared to discuss any challenges. Looking forward to a productive session. Best.
#
# Friendly Reminder:
#
# "Hello rohit, Just a quick reminder about our dinner plans this Saturday at 7:00 PM. Looking forward to catching up with you. If there are any changes, please let me know. Take care, sumit"
#
# Personal Update:
#
# "Hi Mom and Dad, I wanted to update you on how things are going. I recently started a new project at work, and it's been really exciting. I've also been taking some time to explore the city on weekends. I'll call you soon to share more details. Love, sumit"
#
# Appointment Confirmation:
#
# "Dear ram, This is a confirmation of your appointment with Dr. Smith on Thursday, February 13th at 2:00 PM. If you need to reschedule, please contact our office at your earliest convenience. Thank you,ramu"
#
# Event Invitation:
#
# "Dear kumdu, We are pleased to invite you to our annual charity gala on March 15th at 6:30 PM. The event will be held at the Grand Ballroom and will feature a dinner, live music, and an auction. We hope you can join us for this special evening. Best regards, ramesh"

# %%
in_data = ["Hi Team, I hope this email finds you well. I wanted to remind everyone about the upcoming project meeting on Friday at 10:00 AM. Please ensure that you have completed your assigned tasks and be prepared to discuss any challenges. Looking forward to a productive session."]
in_data_feature = feature_extraction.transform(in_data)  # corrected typo
prediction = model.predict(in_data_feature)  # corrected typo
# print(prediction)
if prediction[0] == 1:
    print('ham mail')
else:
    print('spam mail')
# Out:
# ham mail

# %%
in_data = ["""Good morning!

 

Have you noticed the rise of niche travel experiences lately? From concerts to sports, Indians are going the distance to catch the action live. In fact, sports tourism has always been part of India’s travel scene, but recently, it’s reached an entirely new scale. Just think about how many people you know who would travel to watch India play a final. But what’s driving this shift? We explore the trend in today’s edition. Read on to get the deets.

THE MAIN STORY

­
Travel
­	
(Pine)apple A Day


The newest sustainable design choice? Pineapple skin for decor

Who would’ve thought pineapple leaves could shape the future of design? In the Philippines, what was once agricultural waste is now pinyapel — a sustainable material turning up in everything from wall panels to lighting fixtures. Pinyapel, a material crafted from repurposed pineapple fibres, is redefining eco-conscious interiors with its natural texture and refined aesthetic.

 

The journey of pinyapel begins with locally-sourced pineapple leaves, carefully dried, pulped, and pressed into durable sheets. The result is a unique, textured material that seamlessly blends sustainability with style. Its neutral tones and natural fibres allow it to complement a wide range of designs, from minimalist to rustic.

 

Beyond wall panels and furniture, the material is also making its way into everyday living spaces in creative ways. It is used in lighting design, where its organic texture diffuses light beautifully, creating a warm, natural ambiance. On the other hand, some designers are experimenting with it in cabinetry and decorative partitions, offering a sustainable alternative to wood. In commercial spaces, it is finding its place in eco-friendly packaging, artisanal paper products, and even biodegradable coffee cups, reinforcing its practicality beyond interiors.

 

As artisans and designers continue to explore its versatility, pinyapel is becoming a statement. By transforming agricultural byproducts into purposeful design, it showcases the potential of natural resources, turning something once overlooked into something truly extraordinary.

SNAPSHOTS

­

IN A MINUTE

­
In Granada, flamenco is a living tradition, deeply tied to Andalusian, Romani, and Moorish heritage. The city’s Sacromonte caves echo with the sounds of soulful singing, rhythmic guitar, and percussive footwork, carrying on an art form passed down through generations. Performances there feel intimate and raw, whether in a historic tablao or an impromptu street gathering. More than entertainment, flamenco in Granada reflects history, resilience, and deep emotion — expressed through every note, movement, and heartfelt verse.

One of the finest places to witness this seasonal spectacle is a former royal hunting ground in Rajasthan, Keoladeo National Park is now one of the finest places to witness this seasonal spectacle. Its marshes shelter a diverse array of birdlife, from painted storks to the rare Siberian crane. Further east, Odisha’s Chilika Lake, which is India’s largest coastal lagoon, comes alive with several migratory birds, including elegant flamingos, making it a prime spot for birdwatching this time of year.

 

In the Himalayas, Pangot, near Nainital, offers sightings of rare species like the Himalayan rubythroat, while Assam’s Dibru-Saikhowa National Park is a refuge for both birds and birdwatchers alike. Even in bustling Gujarat, the salt pans of the Little Rann of Kutch come alive with greater flamingos and raptors.

 

For those willing to embrace early mornings and quiet patience, birding in India is a revelation — where many a rustling branch and distant call hints at a rare sighting.

ICYMI
Have you ever wondered who knows an author best? Is it the reader or perhaps their editor? Maybe it is their translator. Someone who puts the effort into understanding what is said between the lines. And based on that premise, maybe if an author goes missing, the translators are the ones who should look for them. If that’s a story you find intriguing, you’re in for a treat. Because it’s exactly what Jennifer Croft’s next is about. Read on to get all the deets. pearljamIn 2021, a 17-second extract from a supposed ‘80s song was put online. The uploader, however, was unable to remember its name. Three years since, entire communities are thriving around this purported tune, which everyone seems to recognize, but no one is able to pinpoint to. What’s your guess? Indian organisations are now making a pivot to prioritise performance outcomes over the number of hours worked. A survey revealed that 70 percent of employers now evaluate employee effectiveness based on the quality of their work rather than the time spent at their desks. Companies have also recognized the importance of rest breaks, with 90 percent acknowledging their positive impact on long-term productivity. This shift in mindset signals a positive evolution in India’s corporate culture. What do you think?A song that everyone recognizes, yet no one knows… As hybrid work becomes even more common, so does the need for a new way of looking at the balance between our professional and personal spheres. It can be tricky to maintain boundaries, considering the nature of our workspaces. But this handy guide will help you ensure a healthy equilibrium in your hybrid life.What do you think the recipe to success is – hard work or talent? While maestros may give you different theories, with many emphasising on the importance of hard work, recent research shows that doing so in work situations is more likely to backfire due to the phenomenon of ‘naturalness bias’.People tend to value those with an innate gift more than those who have had to strive for their success. Say you interviewed for a job you were qualified for. During the interview, you demonstrated grit and determination, but the role went to a less qualified candidate instead. Why? Because the interviewees believed their achievements arose from natural talent. This is an example of ‘naturalness bias’.Talent > Hard Work?EVERYDAY AWE

How did you like today's edition?

­

Loved it!


Mehhh


Didn't like it

We Rely on You

As a free publication, we rely almost entirely on readers like you to share The Jurni with your colleagues and friends.

A man on sofa
If you have been moved, thought about the world differently, or have learned something new after reading even one of our editions, please share the link with those who relish new ideas and learning.

 Image credits: DTI.DesignCenterPH / facebook, iamsanatarora/ Instagram

­
© 2025 Jurni Media Group. 

All rights reserved. 

Regent Street London, W1B 3HH UK 

­
You can unsubscribe and break our hearts!

."""]
in_data_feature = feature_extraction.transform(in_data)  # corrected typo
prediction = model.predict(in_data_feature)  # corrected typo
# print(prediction)
if prediction[0] == 1:
    print('ham mail')
else:
    print('spam mail')
# Out:
# ham mail
